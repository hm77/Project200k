# %% [markdown]
# ## Question 1:
#
# The string "PAYPALISHIRING" is written in a zigzag pattern on a given number of rows like this: (you may want to display this pattern in a fixed font for better legibility)
#
# P A H N A P L S I I G Y I R And then read line by line: "PAHNAPLSIIGYIR"
#
# Write the code that will take a string and make this conversion given a number of rows:
#
# string convert(string s, int numRows);
#
# ~~~~
# Example 1:
#
# Input: s = "PAYPALISHIRING", numRows = 3
#
# Output: "PAHNAPLSIIGYIR"
# ~~~~
#
# ~~~~
# Example 2:
#
# Input: s = "PAYPALISHIRING", numRows = 4
#
# Output: "PINALSIGYAHRPI"
#
# Explanation:
#
# P     I    N
# A   L S  I G
# Y A   H R
# P     I
# ~~~~

# %% [markdown]
# #### Rough Notes :
#
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# num row 3
# ~~~~~~~
# 2-1
# 3-3
# 4-5
# 5-7
# 6-9
# 7-11
# 8-13
# 9-15
# ~~~~~~
#
#
# ~~~~
# 3 1 1
# 4 3 1
# 5
# 6
#
#
# ~~~~
# ~~~~~
# A         K         U
# B       J L       T V
# C     I   M     S   W
# D   H     N   R     X
# E G       O Q       Y
# F         P         Z
# ~~~~~~
#
#
# ![rough_work](https://github.com/hm77/Project200k/edit/master/hm77/rough_work_1.jpg "Title")

# %%
class Solution(object):
    def convert(self, s, numRows):
        """
        :type s: str
        :type numRows: int
        :rtype: str
        """
        if numRows ==1:
            return s
        level = 0
        output_str = []
        while(level<numRows):
            idx = 2*(numRows-level)-2 if (2*(numRows-level)-2)>0 else 0 
            idx2 = ((2*(numRows - (numRows - level-1))) -2) if (((2*(numRows - (numRows - level-1))) -2))>0 else 0
            flag = True
            i = level
            while(i<len(s)):
                
                if flag ==True:
                    if idx>0:
                        output_str.append(s[i])
                    i += idx
                    flag = False
                else:
                    if idx2>0:
                        output_str.append(s[i])
                    i+=idx2
                    flag = True
            
            level+=1
        return "".join(output_str)

# %%
s = Solution()
assert s.convert("PAYPALISHIRING", 4)=="PINALSIGYAHRPI"
